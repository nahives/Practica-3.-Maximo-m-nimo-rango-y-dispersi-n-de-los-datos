# %% [markdown]
# <a href="https://colab.research.google.com/github/nahives/Practica-3.-Maximo-m-nimo-rango-y-dispersi-n-de-los-datos/blob/main/Practica_3_Maximo%2C_m%C3%ADnimo%2C_rango_y_dispersi%C3%B3n_de_los_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *

# %%
#lista de calificciones del grupo a pobabilidad y estadistica
grupoa= {70,70,65,95,45,80,73,20,100,96}
print(grupoa)
# Out:
# {96, 65, 100, 70, 73, 45, 80, 20, 95}

# %%
# la funcion type nos devuelve el tipo de dato de la variale
type(grupoa)
# Out:
# set

# %%
promedio= sum(grupoa)/ len(grupoa)
print(promedio)
# Out:
# 71.55555555555556

# %%
# utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2= mean(grupoa)
print(promedio2)
# Out:
# 71.55555555555556

# %%
# determinar el valor de la media con la fn median
mediana= median(grupoa)
print(mediana)
# Out:
# 73

# %%
# deteminar el valor de la moda con la fn mode
moda= mode(grupoa)
print(moda)
# Out:
# 96

# %% [markdown]
# ## EJEMPLO 2. TIEMPO DE 100 METROS DE U GRUPO DE 12 ALUMNOS.

# %%
#DEFINIMOS UNA VARIABLE LLAMADA TIEMPOS100MTS DE TIPO LISTA , QUE CONTIENEN LOS TIEMPOS QUE TARDAD LOS 10 ALMUNOS P;ARA CORRER LOS 100MTS
tiempos100mts=[15,10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)
# Out:
# [15, 10, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("el tiempo promedio de los corredores es=>", mean(tiempos100mts))
# Out:
# el tiempo promedio de los corredores es=> 16.64727272727273

# %%
mediana= median(tiempos100mts)
print("la media de los tiempos de los corredores es =>",mediana)
# Out:
# la media de los tiempos de los corredores es => 17.2

# %%
moda= mode(tiempos100mts)
print("la moda de los tiempos es=>",moda)
# Out:
# la moda de los tiempos es=> 17.2

# %%
multimodas=multimode(tiempos100mts)
print("la  moda de los tiempos es =>", multimodas)
# Out:
# la  moda de los tiempos es => [17.2]

# %% [markdown]
# ## Nueva sección

# %% [markdown]
# ## Ejemplo 3: Histogramas de 2 grupos

# %%
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio= round (random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [64.5, 54.0, 61.52, 60.16, 53.39, 96.67, 79.16, 81.24, 73.33, 90.28, 52.93, 58.93, 64.55, 71.9, 73.02, 68.44, 50.33, 59.05, 58.89, 50.63, 76.94, 52.92, 58.18, 82.24, 99.59, 94.89, 59.06, 68.27, 86.8, 88.59, 84.9, 74.82, 69.77, 91.52, 66.95, 84.17, 60.48, 75.24, 66.19, 66.64, 56.77, 62.62, 59.11, 51.3, 78.96, 68.33, 74.97, 50.59, 96.52, 65.17, 77.85, 59.46, 90.02, 53.48, 69.86, 66.14, 70.56, 59.11, 57.77, 74.6, 93.86, 82.74, 82.2, 76.51, 89.87, 82.87, 97.32, 99.23, 95.96, 50.48, 88.91, 97.77, 91.57, 54.36, 58.91, 85.43, 82.53, 54.86, 85.35, 82.64, 97.3, 70.41, 95.58, 52.94, 53.71, 67.78, 97.64, 74.95, 57.48, 79.84, 95.31, 76.21, 76.98, 71.03, 98.06, 69.05, 94.56, 75.26, 92.14, 68.35]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2= round (random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [80.62, 98.06, 75.01, 86.97, 77.29, 89.06, 72.35, 61.2, 86.18, 62.53, 87.66, 81.82, 98.7, 65.22, 88.25, 78.97, 71.12, 89.87, 57.9, 83.19, 71.66, 53.05, 56.95, 55.95, 88.06, 75.92, 67.19, 88.71, 78.17, 66.51, 99.69, 91.23, 73.81, 67.34, 61.3, 54.01, 63.72, 78.66, 88.83, 65.74, 82.48, 64.71, 59.03, 97.47, 77.99, 51.61, 67.08, 64.74, 76.45, 94.46, 82.79, 62.88, 74.73, 66.32, 79.27, 79.15, 72.97, 61.91, 67.15, 66.79, 73.28, 87.13, 82.09, 93.1, 76.07, 99.58, 98.61, 65.49, 59.29, 54.07, 62.66, 99.49, 95.57, 99.42, 50.71, 88.78, 72.02, 77.14, 60.57, 52.12, 55.27, 54.0, 56.02, 89.75, 73.04, 92.81, 59.91, 98.09, 62.61, 57.7, 91.49, 65.18, 99.74, 68.72, 63.43, 92.27, 77.58, 58.44, 83.18, 89.96]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
media= mean(fabrica1)
mediana= median(fabrica1)
moda= mode(fabrica1)

print("valores de la fabrica 1")
print("la media es=", media)
print("la mediana es=",mediana)
print("la moda es=",moda)
# Out:
# valores de la fabrica 1
# la media es= 73.7222
# la mediana es= 73.175
# la moda es= 59.11

# %%
media= mean(fabrica2)
mediana= median(fabrica2)
moda= mode(fabrica2)

print("valores de la fabrica 2")
print("la media es=", media)
print("la mediana es=",mediana)
print("la moda es=",moda)
# Out:
# valores de la fabrica 2
# la media es= 75.2483
# la mediana es= 74.87
# la moda es= 80.62

# %%
# generar 2 subplot de 1 reglon por 2 columnas para esplegar los 2 histogramas,
# uno al lado de la otra
fig,(ax1, ax2) =plt.subplots(nrows=1, ncols=2)

# %%
fig,(ax1, ax2) =plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo , maximo, rango

media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)

# %%
plt.hist(fabrica1, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle= "dashed", linewidth= 2, label= 'Mediana')
plt.axvline(moda1, color='y' , linestyle ='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)

plt.hist(fabrica2, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle= "dashed", linewidth= 2, label= 'Mediana')
plt.axvline(moda2, color='y' , linestyle ='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Maximo, minimo y rango

# %%
maximo= max(fabrica1)
minimo= min(fabrica1)
rango=maximo-minimo
media=mean(fabrica1)
mediana= median(fabrica1)
moda= mode(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "media=", media, "\n mediana =",mediana,"\n moda =",moda,"\n maximo=",maximo, "\n minimo=",minimo,"\n rango=",rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media= 73.7222
#  mediana = 73.175
#  moda = 59.11
#  maximo= 99.59
#  minimo= 50.33
#  rango= 49.260000000000005

# %%
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2=maximo-minimo
media2=mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "media=", media2, "\n mediana =",mediana2,"\n moda =",moda2,"\n maximo=",maximo2, "\n minimo=",minimo2,"\n rango=",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media= 75.2483
#  mediana = 74.87
#  moda = 80.62
#  maximo= 99.74
#  minimo= 50.71
#  rango= 49.260000000000005

# %% [markdown]
# ## DISPERCION DE LOS DATOS

# %%
desviacion_estandar_fabrica1= stdev(fabrica1)
print("la desviacion de la fabrica 1 es =", desviacion_estandar_fabrica1)
# Out:
# la desviacion de la fabrica 1 es = 14.878407008517785

# %%
desviacion_estandar_fabrica2= stdev(fabrica2)
print("la desviacion de la fabrica 2 es =", desviacion_estandar_fabrica2)
# Out:
# la desviacion de la fabrica 2 es = 14.239699878732123

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle= "dashed", linewidth= 2, label= f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y' , linestyle ='dashed', linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1 , color='black', linestyle='dashed', linewidth=2, label='Desv. Estandar')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media:.2f}')
plt.axvline(mediana2, color='r', linestyle= "dashed", linewidth= 2, label= f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y' , linestyle ='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2 , color='black', linestyle='dashed', linewidth=2, label='Desv. Estandar')
plt.axvline(media2 + desviacion_estandar_fabrica2 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica2:.2f}')
plt.xlabel('Valor')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 2")
plt.legend()
plt.show()
